# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
df = pd.DataFrame({
    'study_hours' : [2,3,5,1,4,6],
    'sleep_hours' : [7,8,6,5,7,6],
    'attendance' : [80,85,90,70,88,95],
    'practice_test' : [1,2,4,0,3,5],
    'score' : [65,70,85,60,80,90]
})

# %%
x = df.drop(['score'],axis=1)
# print(x)
y = df['score']
print(y)
# Out:
# 0    65
# 1    70
# 2    85
# 3    60
# 4    80
# 5    90
# Name: score, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model.fit(x_train,y_train)
model.predict([[3,5,70,3]])
# Out:
# C:\Users\behra\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([93.33333333])
